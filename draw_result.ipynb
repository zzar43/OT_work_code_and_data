# %%
using JLD2, PyPlot

# %%
@load "temp_data/data_iter_5.jld2"
# Out:
# 2-element Array{Symbol,1}:
#  :xk
#  :ggk

# %%
Nx = 101
Ny = 101

imshow(reshape(xk, Nx, Ny), cmap="viridis"); colorbar(); clim(3,3.4)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
Nx = 101
Ny = 101

imshow(reshape(xk, Nx, Ny), cmap="magma_r"); colorbar(); clim(3,3.6)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
