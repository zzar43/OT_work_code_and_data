# %%
using JLD2, PyPlot

# %%
@load "temp_data/data.jld2"
# Out:
# 2-element Array{Symbol,1}:
#  :xk
#  :update_direction

# %%
@load "temp_data/data_iter_20.jld2"
subplot(211)
imshow(reshape(xk, Nx, Ny), cmap="magma_r", aspect=1.5); clim(minimum(c_true), maximum(c_true))
subplot(212)
gradk = copy(update_direction)
vv = 0.5min(abs.(minimum(gradk)), abs.(maximum(gradk)))
imshow(reshape(gradk, Nx, Ny), cmap="bwr", aspect=1.5); clim(-vv,vv)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
@load "temp_data/mixed_ot_1-20/data_iter_10.jld2"
subplot(211)
imshow(reshape(xk, Nx, Ny), cmap="magma_r", aspect=1.5); clim(minimum(c_true), maximum(c_true))
subplot(212)
gradk = copy(update_direction)
vv = 0.5min(abs.(minimum(gradk)), abs.(maximum(gradk)))
imshow(reshape(gradk, Nx, Ny), cmap="bwr", aspect=1.5); clim(-vv,vv)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
@load "OT_work/Ex_4/temp_data/l2_1-50/data_iter_4.jld2"
# Out:
# 2-element Array{Symbol,1}:
#  :xk
#  :update_direction

# %%
imshow(reshape(xk, Nx, Ny), cmap="viridis_r"); colorbar();
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
imshow(reshape(gradk, Nx, Ny), cmap="viridis_r"); colorbar();
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
@load "OT_work/Ex_4/ex4_data.jld2"
@load "OT_work/Ex_4/temp_data/ot_new_1-20/data_iter_5.jld2"
# Out:
# 2-element Array{Symbol,1}:
#  :xk
#  :update_direction

# %%
subplot(211)
imshow(reshape(xk, Nx, Ny), cmap="magma_r");
subplot(212)
gradk = copy(update_direction)
vv = 0.5min(abs.(minimum(gradk)), abs.(maximum(gradk)))
imshow(reshape(gradk, Nx, Ny), cmap="bwr"); clim(-vv,vv)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
@load "OT_work/Ex_4/ex4_data.jld2"
# Out:
# 16-element Array{Symbol,1}:
#  :received_data
#  :c
#  :c_true
#  :rho
#  :Nx
#  :Ny
#  :h
#  :Fs
#  :Nt
#  :dt
#  :t
#  :source
#  :source_position
#  :receiver_position
#  :pml_len
#  :pml_coef

# %%
Nt
# Out:
# 2000

# %%
xk
# Out:
# 25284×1 Array{Float64,2}:
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  1.5
#  ⋮
#  3.725688977448273
#  3.7736819076337045
#  3.818746909661628
#  3.8630007733839866
#  3.9060507757483762
#  3.9480370284625863
#  3.9881572872833315
#  4.027394485308238
#  4.065232893947666
#  4.1014684607926855
#  4.1360088537201385
#  4.167698442777287
